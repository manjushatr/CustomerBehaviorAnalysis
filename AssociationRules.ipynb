# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Loading the data set
marketbasketdf = pd.read_csv('data/clean_basketdf.csv', index_col=0, decimal='.')

# %%
marketbasketdf.head()
# Out:
#    BasketID           BasketDate  Sale  CustomerID CustomerCountry  ProdID  \
# 0    536365  2010-12-01 08:26:00  2.55     17850.0  United Kingdom  85123A
# 1    536365  2010-12-01 08:26:00  3.39     17850.0  United Kingdom   71053
# 2    536365  2010-12-01 08:26:00  2.75     17850.0  United Kingdom  84406B
# 3    536365  2010-12-01 08:26:00  3.39     17850.0  United Kingdom  84029G
# 4    536365  2010-12-01 08:26:00  3.39     17850.0  United Kingdom  84029E
#
#                              ProdDescr  Qta  Amount
# 0   WHITE HANGING HEART T-LIGHT HOLDER    6   15.30
# 1                  WHITE METAL LANTERN    6   20.34
# 2       CREAM CUPID HEARTS COAT HANGER    8   22.00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE    6   20.34
# 4       RED WOOLLY HOTTIE WHITE HEART.    6   20.34

# %%
transactions = marketbasketdf.groupby(['BasketID'])['ProdDescr'].apply(list)
baskets = transactions.values

print("NUM OF BASKETS: {}".format(len(baskets)))
# Out:
# NUM OF BASKETS: 18532

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# convert data in format which is required 
# converting using pivot table and Quantity sum as values. fill 0 if any nan values

basket = pd.pivot_table(data=marketbasketdf,index='BasketID',columns='ProdDescr',values='Qta', aggfunc='sum',fill_value=0)

# %%
basket.head()
# Out:
# ProdDescr   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# BasketID
# 536365                                  0                               0
# 536366                                  0                               0
# 536367                                  0                               0
# 536368                                  0                               0
# 536369                                  0                               0
#
# ProdDescr   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# BasketID
# 536365                      0                             0
# 536366                      0                             0
# 536367                      0                             0
# 536368                      0                             0
# 536369                      0                             0
#
# ProdDescr   I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# BasketID
# 536365                                0                         0
# 536366                                0                         0
# 536367                                0                         0
# 536368                                0                         0
# 536369                                0                         0
#
# ProdDescr   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# BasketID
# 536365                               0                         0
# 536366                               0                         0
# 536367                               0                         0
# 536368                               0                         0
# 536369                               0                         0
#
# ProdDescr   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# BasketID                                                              ...
# 536365                                    0                        0  ...
# 536366                                    0                        0  ...
# 536367                                    0                        0  ...
# 536368                                    0                        0  ...
# 536369                                    0                        0  ...
#
# ProdDescr  ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# BasketID
# 536365                             0                          0
# 536366                             0                          0
# 536367                             0                          0
# 536368                             0                          0
# 536369                             0                          0
#
# ProdDescr  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# BasketID
# 536365                                    0                               0
# 536366                                    0                               0
# 536367                                    0                               0
# 536368                                    0                               0
# 536369                                    0                               0
#
# ProdDescr  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# BasketID
# 536365                                   0                                0
# 536366                                   0                                0
# 536367                                   0                                0
# 536368                                   0                                0
# 536369                                   0                                0
#
# ProdDescr  ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# BasketID
# 536365                                  0                                 0
# 536366                                  0                                 0
# 536367                                  0                                 0
# 536368                                  0                                 0
# 536369                                  0                                 0
#
# ProdDescr  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# BasketID
# 536365                               0                                 0
# 536366                               0                                 0
# 536367                               0                                 0
# 536368                               0                                 0
# 536369                               0                                 0
#
# [5 rows x 3877 columns]

# %%
#this to check correctness after binning it to 1 ..
basket['10 COLOUR SPACEBOY PEN'].head(10)
# Out:
# BasketID
# 536365    0
# 536366    0
# 536367    0
# 536368    0
# 536369    0
# 536370    0
# 536371    0
# 536372    0
# 536373    0
# 536374    0
# Name: 10 COLOUR SPACEBOY PEN, dtype: int64

# %%
# we dont need quantity sum 
# we need either has taken or not 
# so if user has taken that item mark as 1 else mark as 0.

def convert_into_binary(x):
    if x > 0:
        return 1
    else:
        return 0

# %%
basket_sets = basket.applymap(convert_into_binary)

# %%
# check : has quantity now converted to 1 or 0.
basket_sets['10 COLOUR SPACEBOY PEN'].head(10)
# Out:
# BasketID
# 536365    0
# 536366    0
# 536367    0
# 536368    0
# 536369    0
# 536370    0
# 536371    0
# 536372    0
# 536373    0
# 536374    0
# Name: 10 COLOUR SPACEBOY PEN, dtype: int64

# %%
# remove postage item as it is just a seal which almost all transaction contains. 
print(basket_sets['POSTAGE'].head())

basket_sets.drop(columns=['POSTAGE'],inplace=True)
# Out:
# BasketID
# 536365    0
# 536366    0
# 536367    0
# 536368    0
# 536369    0
# Name: POSTAGE, dtype: int64

# %%
# call apriori function and pass minimum support here we are passing 7%. 
# means 7 times in total number of transaction the item should be present.
frequent_itemsets = apriori(basket_sets, min_support=0.02, use_colnames=True)
# Out:
# C:\Users\Manjusha\AppData\Roaming\Python\Python310\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
#it will generate frequent itemsets 
frequent_itemsets
# Out:
#     support                              itemsets
# 0  0.074196       (ASSORTED COLOUR BIRD ORNAMENT)
# 1  0.086337             (JUMBO BAG RED RETROSPOT)
# 2  0.074412                       (PARTY BUNTING)
# 3  0.091895            (REGENCY CAKESTAND 3 TIER)
# 4  0.106357  (WHITE HANGING HEART T-LIGHT HOLDER)

# %%
# We would apply association rules on frequent itemset. 
# here we are setting based on lift and keeping minimum lift as 1

rules_mlxtend = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules_mlxtend.head()
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
# rules_mlxtend.rename(columns={'antecedents':'lhs','consequents':'rhs'})

# as based business use case we can sort based on confidance and lift.
rules_mlxtend[ (rules_mlxtend['lift'] >= 4) & (rules_mlxtend['confidence'] >= 0.8) ].head()
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []
